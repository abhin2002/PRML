# %% [markdown]
# # Pattern Recognition and Machine Learning
# ## Programming Test - 01

# %% [markdown]
# #### Q1) Fill in the below table based on the given dataset file sample_dataset.csv. [6 marks]
#
# | S.No. | Dataset | Sample Dataset |
# |-------|---------|------|
# | 1.    | Feature vector dimension |   |
# | 2.    | Number of classes        |   |
# | 3.    | Number of Samples / Class|   |
# | 4.    | Prior probabilities of each class |  |
# | 5.    | Mean vector dimension    |   |
# | 6.    | Covariance matrix dimension |  |

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("sample_dataset.csv")

label_col = df.columns[-1]
X = df.drop(columns=[label_col]).to_numpy()
y = df[label_col].to_numpy()

# ----------------- write your code below ----------------- #

# %% [markdown]
# #### Q2) Consider given test samples:
#
# - x = [6.0, 2.7, 5.0, 1.4]
# - y = [5.2, 3.4, 1.8, 0.5]
# - z = [6.9, 3.1, 6.0, 1.5]
#
# **A. Perform KNN classification using L₂ distance and K=1,Update the results in the following table. [6 marks]**
#
# | Sample | Minimum Distance | Class |
# |--------|------------------|-------|
# | x      |                  |       |
# | y      |                  |       |
# | z      |                  |       |
#
# **B. Write a program to perform Bayesian classification of the given test samples, using Class Likelihoods,**<br>
# **assuming them to be Multivariate Gaussian. Update the class statistics in Table 1. and maximum likelihood results in Table 2. [12 marks]**
#
# Table 1
# | Class | Mean Vector | Determinant of Covariance Matrix |
# |-------|-------------|-----------------|
# |       |             |                 |
# |       |             |                 |
# |       |             |                 |
#
# Table 2
# | Sample | Maximum Likelihood | Class |
# |--------|---------------|-------|
# |        |               |       |
# |        |               |       |
# |        |               |       |
#
# **C. Indicate whether the classification would change if posterior probabilities are considered ___ (Yes/No) [1 mark]**
#
# **Note 1:** You can use `numpy.linalg.inv()` and `numpy.linalg.det()` to calculate inverse and determinant.
#
# **Note 2:** Express all numerical answers to two non-zero decimals,
# or in scientific notation of the form *a.bc × e⁻ⁿ*.

# %%
# A.
def KNN_classifier(X,y,sample):
  prediction = None
  min_dist = 0
  # ----------------- write your code above ----------------- #
  

  return prediction, min_dist

samples = np.array([
    [6.0, 2.7, 5.0, 1.4],
    [5.2, 3.4, 1.8, 0.5],
    [6.9, 3.1, 6.0, 1.5]
])

# ----------------- write your code above ----------------- #

# %%
# B.

def gaussian_likelihood(x, mean, cov):
    prob = None
    # ----------------- write your code above ----------------- #
    
    return prob

def bayes_classify(x):

    max_like = None
    pred_class = None
    # ----------------- write your code above ----------------- #

    return pred_class, max_like

samples = np.array([
    [6.0, 2.7, 5.0, 1.4],
    [5.2, 3.4, 1.8, 0.5],
    [6.9, 3.1, 6.0, 1.5]
])

# ----------------- write your code above ----------------- #
